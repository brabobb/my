# %%
import csv
f = open('age.csv')
data = csv.reader(f)

for row in data:
    if '신도림' in row[0]:
        print(row)
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '37513', '37513', '378', '413', '437', '412', '423', '418', '467', '414', '414', '416', '396', '362', '386', '339', '341', '351', '368', '391', '351', '387', '444', '432', '484', '449', '490', '431', '511', '445', '507', '517', '507', '566', '611', '638', '750', '772', '789', '756', '822', '679', '731', '690', '693', '734', '725', '658', '632', '602', '571', '572', '490', '500', '553', '549', '487', '537', '590', '585', '513', '515', '492', '422', '527', '397', '396', '403', '258', '314', '273', '303', '297', '197', '172', '158', '166', '186', '152', '141', '108', '118', '88', '97', '73', '70', '47', '45', '42', '27', '32', '21', '25', '23', '13', '7', '10', '6', '3', '3', '2', '2', '6']

# %%
f = open('train.csv')
data = csv.reader(f)

for row in data:
    print('2017 매출액:', row[7], '2016 매출액:', row[17])
# Out:
# 2017 매출액: revenue1 2016 매출액: quickAsset1
# 2017 매출액: 4217530010 2016 매출액: 997671878
# 2017 매출액: NA 2016 매출액: NA
# 2017 매출액: 1004521989 2016 매출액: 253682170
# 2017 매출액: 72507342181 2016 매출액: 11534749645
# 2017 매출액: 49043538016 2016 매출액: 5873265455
# 2017 매출액: 33580536703 2016 매출액: 5481680248
# 2017 매출액: 22552179836 2016 매출액: 11236305651
# 2017 매출액: 64359169160 2016 매출액: 11879215739
# 2017 매출액: 12748392940 2016 매출액: 4119094934
# 2017 매출액: 41406077905 2016 매출액: 3924282684
# 2017 매출액: 49669173562 2016 매출액: 11172140366
# 2017 매출액: 14819927146 2016 매출액: 3921154973
# 2017 매출액: 2998495883 2016 매출액: 1208023892
# 2017 매출액: 66977875101 2016 매출액: 9778297467
# 2017 매출액: NA 2016 매출액: NA
# 2017 매출액: 1.24E+11 2016 매출액: 18872481981
# 2017 매출액: 15690699439 2016 매출액: 3689155191
# 2017 매출액: 38928596428 2016 매출액: 22361993468
# 2017 매출액: 6857075503 2016 매출액: 788366733
# 2017 매출액: 22920991463 2016 매출액: 5412264543
# 2017 매출액: 17096005437 2016 매출액: 2225171415
# 2017 매출액: 67068990371 2016 매출액: 18244190311
# ...
